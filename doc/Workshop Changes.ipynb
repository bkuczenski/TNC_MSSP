# %%
import os,sys
sys.path.append('../src')

import MSSP

# %%
from MSSP.workshop import *

# %%
E = load_engine()

# %%
check_questions_on_sheet(E, 'Assessment')
# Out:
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# set title
# add extras
# update title string
# Find question ID
# Assessment row 22: Found 0 matches; cannot isolate question ID
# update title string
# ...

# %%
check_questions_on_sheet(E, 'ControlRules')
# Out:
# update title string
# Old: Highly migratory?
# New: Is the species highly migratory?
# Find question ID
# set title
# attribute map - 1 found
# set category
# attribute map - 1 found
# add extras
# update title string
# Old: Largely sedentary/sessile?
# New: Is the species largely largely sedentary or sessile?
# Find question ID
# set title
# attribute map - 1 found
# set category
# attribute map - 1 found
# add extras
# update title string
# Old: Determinate growth?
# New: Does the species exhibit determinate growth?
# Find question ID
# set title
# attribute map - 1 found
# set category
# attribute map - 1 found
# add extras
# update title string
# Find question ID
# set title
# set category
# attribute map - 1 found
# add extras
# update title string
# Find question ID
# set title
# set category
# attribute map - 1 found
# add extras
# update title string
# Old: Sexually dimorphic growth?
# New: Does the specis exhibit sexually dimorphic growth?
# Find question ID
# set title
# ...

# %%
check_questions_on_sheet(E, 'Monitoring')
# Out:
# update title string
# Find question ID
# add extras
# update title string
# Find question ID
# add extras
# update title string
# Find question ID
# add extras
# update title string
# Find question ID
# add extras
# update title string
# Find question ID
# set title
# set category
# add extras
# update title string
# Find question ID
# set title
# set category
# attribute map - 1 found
# add extras
# update title string
# Find question ID
# set title
# set category
# attribute map - 1 found
# add extras
# update title string
# Find question ID
# add extras
# update title string
# Find question ID
# set title
# set category
# attribute map - 1 found
# add extras
# update title string
# Find question ID
# set title
# set category
# attribute map - 1 found
# add extras
# update title string
# Find question ID
# set title
# set category
# add extras
# update title string
# Find question ID
# set title
# set category
# add extras
# update title string
# ...

# %%
save_engine(E)
# Out:
# Creating 189 questions...
# Creating 143 targets...
# Creating 528 criteria...
# Creating 2054 caveats...
# Creating 707 attributes...
# Creating 247 notes...
# Creating colormap...
# Output written to folder /Users/brandon/Documents/GitHub/SNAP Fisheries Spreadsheets/json/2016-05-27a/.
