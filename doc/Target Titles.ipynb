# %%
import os,sys
sys.path.append('../src')

import MSSP

# %%
from MSSP.target_titles import *

# %%
E = run_update()
# Out:
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# attribute map - 1 found
# ...
